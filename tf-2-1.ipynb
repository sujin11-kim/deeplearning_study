# %%
import numpy as np
import tensorflow as tf

# %%
#학습 data set
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# %%
tf.model = tf.keras.Sequential() #tf 모델 정의
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1)) 
# units : output shape, input_dim : input shape

# %%
sgd = tf.keras.optimizers.SGD(learning_rate=0.1)  
# SGD : standard gradient descendent 알고리즘 이용, lr : 학습 비율
tf.model.compile(loss='mse', optimizer=sgd)  
# mse : mean_squared_error, 1/m * sig (y'-y)^2

# %%
tf.model.summary() #모델 확인
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.model.fit(x_train, y_train, epochs=200) #data set으로 200번 학습
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 445ms/step - loss: 2.2259
# Epoch 2/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0571
# Epoch 3/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5290
# Epoch 4/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2886
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1777
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1251
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0987
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0844
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0756
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0695
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0646
# Epoch 12/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0604
# ...

# %%
y_predict = tf.model.predict(np.array([5, 4])) #input : 5,4를 넣어 예측값을 얻는다
print(y_predict)
# Out:
# 1/1 [==============================] - 0s 75ms/step
# [[-3.9986548]
#  [-2.999308 ]]
